# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
a=list
plt.plot([1,2,3,4])
plt.ylabel('some numbers')
plt.show()

# %%
a=range(1,100)
def totalprice(peoplenum):
    totaloffer=ticket_price*people_num
    prices=list[75,60,45]
    people_level=list[range(1,40),range(41,80)]

# %%
what1=range(0,2)
what2=range(5,8)

dlist=[what1[0],what2[1]]
#dlist=list[how1,how2]

# %%
x = np.linspace(0, 2 * np.pi, 50)
y = np.sin(x)
plt.scatter(x,y)
plt.show()
